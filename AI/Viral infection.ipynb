# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv(r'C:\Users\ronal\Downloads\New folder\Expanded_Viral_Infection_Dataset.csv')

# %% [markdown]
# # Show And Exploration For Data

# %%
data
# Out:
#            WBCS      RBCs  Haemoglobin  Hematocrit (PCV)      M.C.V  \
# 0     16.870000  3.830000    10.300000         31.200000  81.500000
# 1     11.890000  4.710000    15.200000         47.100000  99.900000
# 2      9.180000  4.180000    12.900000         39.200000  93.600000
# 3      3.850000  6.410000    12.400000         39.400000  61.400000
# 4      8.100000  3.290000     8.700000         27.500000  83.500000
# ...         ...       ...          ...               ...        ...
# 1995   6.138852  3.892169    14.066638         37.441422  81.426354
# 1996   4.604680  4.617072    12.124085         38.399213  88.767748
# 1997   5.078144  4.685320    14.067068         43.724631  79.506802
# 1998   8.640512  4.484617    13.974598         45.669595  94.444405
# 1999   7.589512  3.937660    12.458691         45.364773  86.673093
#
#           M.C.H    M.C.H.C        RDW  Platelets Count        MPV  ...  \
# 0     26.900000  33.000000  15.500000       353.000000   9.400000  ...
# 1     32.300000  32.300000  16.200000       227.000000   8.400000  ...
# 2     30.800000  32.900000  14.900000       249.000000   9.800000  ...
# 3     19.400000  31.500000  20.800000       291.000000   7.500000  ...
# 4     26.500000  31.700000  16.700000       308.000000   8.700000  ...
# ...         ...        ...        ...              ...        ...  ...
# 1995  29.992506  32.135437  13.707895       175.635517  10.240323  ...
# 1996  29.142086  33.441615  11.979198       295.861895   6.813587  ...
# 1997  28.557199  32.908002  12.085093       280.319490   7.602585  ...
# 1998  27.752769  33.491102  12.306308       295.379947  10.976297  ...
# 1999  29.624328  33.660918  11.925320       181.994109  10.405661  ...
#
#       Lymphocytes#  Monocyte%  Monocyte#  Eosinophils%  Eosinophils#  \
# 0         1.636400   5.600000   0.944700      0.000000      0.000000
# 1         0.749100   9.100000   1.082000      0.200000      0.023800
# 2         3.157900   7.800000   0.716000      1.500000      0.137700
# 3         1.093400   9.300000   0.358000      0.700000      0.027000
# 4         1.085400   7.500000   0.607500      3.500000      0.283500
# ...            ...        ...        ...           ...           ...
# 1995      2.263848   6.847393   0.244121      4.167758      0.353508
# 1996      1.761706   5.370831   0.638892      5.796393      0.233932
# 1997      3.492709   4.141940   0.788960      5.958742      0.195580
# 1998      1.724996   7.915454   0.386320      4.524441      0.283791
# 1999      1.828160   9.645708   0.617019      2.726154      0.145927
#
#       Basophils%  Basophils#  Large Unstained Cells%  Large Unstained Cells#  \
# 0       0.100000    0.016900                1.100000                0.100000
# 1       0.100000    0.011900                1.200000                0.140000
# 2       2.000000    0.183600                1.600000                0.150000
# 3       0.300000    0.011600                0.700000                0.030000
# 4       0.300000    0.024300                1.000000                0.090000
# ...          ...         ...                     ...                     ...
# 1995    0.652426    0.024878                1.694804                0.167849
# 1996    0.304750    0.029323                3.958524                0.219323
# 1997    0.454735    0.065784                2.369034                0.105680
# 1998    0.577832    0.097172                0.783931                0.294552
# 1999    0.663608    0.083879                3.944479                0.082294
#
#       Disease_Prediction
# 0                      0
# 1                      0
# 2                      1
# 3                      0
# 4                      1
# ...                  ...
# 1995                   0
# 1996                   0
# 1997                   0
# 1998                   0
# 1999                   0
#
# [2000 rows x 23 columns]

# %%
data['Disease_Prediction'].value_counts()
# Out:
# Disease_Prediction
# 0    1000
# 1    1000
# Name: count, dtype: int64

# %%
data.head(5)
# Out:
#     WBCS  RBCs  Haemoglobin  Hematocrit (PCV)  M.C.V  M.C.H  M.C.H.C   RDW  \
# 0  16.87  3.83         10.3              31.2   81.5   26.9     33.0  15.5
# 1  11.89  4.71         15.2              47.1   99.9   32.3     32.3  16.2
# 2   9.18  4.18         12.9              39.2   93.6   30.8     32.9  14.9
# 3   3.85  6.41         12.4              39.4   61.4   19.4     31.5  20.8
# 4   8.10  3.29          8.7              27.5   83.5   26.5     31.7  16.7
#
#    Platelets Count  MPV  ...  Lymphocytes#  Monocyte%  Monocyte#  \
# 0            353.0  9.4  ...        1.6364        5.6     0.9447
# 1            227.0  8.4  ...        0.7491        9.1     1.0820
# 2            249.0  9.8  ...        3.1579        7.8     0.7160
# 3            291.0  7.5  ...        1.0934        9.3     0.3580
# 4            308.0  8.7  ...        1.0854        7.5     0.6075
#
#    Eosinophils%  Eosinophils#  Basophils%  Basophils#  Large Unstained Cells%  \
# 0           0.0        0.0000         0.1      0.0169                     1.1
# 1           0.2        0.0238         0.1      0.0119                     1.2
# 2           1.5        0.1377         2.0      0.1836                     1.6
# 3           0.7        0.0270         0.3      0.0116                     0.7
# 4           3.5        0.2835         0.3      0.0243                     1.0
#
#    Large Unstained Cells#  Disease_Prediction
# 0                    0.10                   0
# 1                    0.14                   0
# 2                    0.15                   1
# 3                    0.03                   0
# 4                    0.09                   1
#
# [5 rows x 23 columns]

# %%
data.shape
# Out:
# (2000, 23)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   WBCS                    2000 non-null   float64
#  1   RBCs                    2000 non-null   float64
#  2   Haemoglobin             2000 non-null   float64
#  3   Hematocrit (PCV)        2000 non-null   float64
#  4   M.C.V                   2000 non-null   float64
#  5   M.C.H                   2000 non-null   float64
#  6   M.C.H.C                 2000 non-null   float64
#  7   RDW                     2000 non-null   float64
#  8   Platelets Count         2000 non-null   float64
#  9   MPV                     2000 non-null   float64
#  10  Neutrophils%            2000 non-null   float64
#  11  Neutrophils#            2000 non-null   float64
#  12  Lymphocytes%            2000 non-null   float64
#  13  Lymphocytes#            2000 non-null   float64
#  14  Monocyte%               2000 non-null   float64
#  15  Monocyte#               2000 non-null   float64
#  16  Eosinophils%            2000 non-null   float64
#  17  Eosinophils#            2000 non-null   float64
#  18  Basophils%              2000 non-null   float64
#  19  Basophils#              2000 non-null   float64
#  20  Large Unstained Cells%  2000 non-null   float64
#  21  Large Unstained Cells#  2000 non-null   float64
#  22  Disease_Prediction      2000 non-null   int64
# dtypes: float64(22), int64(1)
# memory usage: 359.5 KB

# %%
data.describe()
# Out:
#               WBCS         RBCs  Haemoglobin  Hematocrit (PCV)        M.C.V  \
# count  2000.000000  2000.000000  2000.000000       2000.000000  2000.000000
# mean      4.956802     3.719303    13.369382         40.666661    85.628565
# std       2.999635     0.697076     1.197699          3.641253     5.986383
# min       0.910000     1.230000     1.600000         11.500000    61.400000
# 25%       2.475888     3.119829    12.665104         38.369525    80.555699
# 50%       4.405450     3.832532    13.448761         40.755440    85.543140
# 75%       7.299449     4.313544    14.233919         43.394428    90.779777
# max      35.340000     6.410000    16.900000         52.000000   106.500000
#
#              M.C.H      M.C.H.C          RDW  Platelets Count          MPV  \
# count  2000.000000  2000.000000  2000.000000      2000.000000  2000.000000
# mean     29.424080    33.941971    13.161655       199.527215     8.762826
# std       1.580192     1.186161     1.302390       121.163782     1.323320
# min      19.400000    28.700000    11.501124        13.000000     6.501351
# 25%      28.271939    32.978758    12.293511        99.263015     7.646293
# 50%      29.401512    33.949072    13.067672       154.090659     8.729056
# 75%      30.709840    34.945565    13.832661       296.213920     9.929091
# max      38.200000    39.200000    32.200000       803.000000    13.300000
#
#        ...  Lymphocytes#    Monocyte%    Monocyte#  Eosinophils%  \
# count  ...   2000.000000  2000.000000  2000.000000   2000.000000
# mean   ...      9.240410     6.050114     0.510944      3.936419
# std    ...    303.022229     2.471980     0.197330      1.315698
# min    ...      0.174000     1.500000     0.040000      0.000000
# 25%    ...      1.933443     3.995835     0.357124      2.904301
# 50%    ...      2.447507     6.019283     0.502754      3.924366
# 75%    ...      3.011372     8.009521     0.655590      4.993427
# max    ...  13554.000000    20.000000     2.901000     12.600000
#
#        Eosinophils#   Basophils%   Basophils#  Large Unstained Cells%  \
# count   2000.000000  2000.000000  2000.000000             2000.000000
# mean       0.216130     0.495350     0.049485                1.957962
# std        0.106577     0.295653     0.029492                1.164459
# min        0.000000     0.000000     0.000000                0.000000
# 25%        0.126069     0.235745     0.024247                0.940440
# 50%        0.211927     0.487123     0.049399                1.931149
# 75%        0.304606     0.749755     0.074076                2.964186
# max        0.813600     2.000000     0.183600                8.600000
#
#        Large Unstained Cells#  Disease_Prediction
# count             2000.000000         2000.000000
# mean                 0.148263            0.500000
# std                  0.092685            0.500125
# min                  0.000000            0.000000
# 25%                  0.073333            0.000000
# 50%                  0.146850            0.500000
# 75%                  0.219784            1.000000
# max                  1.360000            1.000000
#
# [8 rows x 23 columns]

# %%
data.duplicated().sum()
# Out:
# 0

# %%
null=data.isnull().sum()
null[null>0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# # Analysis For Data

# %%
data.corr()
# Out:
#                             WBCS      RBCs  Haemoglobin  Hematocrit (PCV)  \
# WBCS                    1.000000  0.653176    -0.154026         -0.116091
# RBCs                    0.653176  1.000000     0.101102          0.105479
# Haemoglobin            -0.154026  0.101102     1.000000          0.420203
# Hematocrit (PCV)       -0.116091  0.105479     0.420203          1.000000
# M.C.V                  -0.030996 -0.039823     0.056299          0.039758
# M.C.H                  -0.094124 -0.064287     0.166227          0.100822
# M.C.H.C                -0.055120 -0.074731     0.126552          0.100805
# RDW                     0.188647  0.078891    -0.269535         -0.222649
# Platelets Count         0.669270  0.698370    -0.026045         -0.043628
# MPV                     0.043953  0.011329    -0.033526         -0.050830
# Neutrophils%            0.095527 -0.010930    -0.055998         -0.053959
# Neutrophils#            0.281147 -0.007854    -0.131118         -0.083889
# Lymphocytes%           -0.105037 -0.014087     0.094218          0.101713
# Lymphocytes#            0.075279  0.000059    -0.075679         -0.066478
# Monocyte%               0.030776  0.020555    -0.133075         -0.138601
# Monocyte#               0.220958  0.062496    -0.096082         -0.077590
# Eosinophils%           -0.110309 -0.007623     0.141148          0.098799
# Eosinophils#           -0.017828 -0.017187     0.071946          0.067273
# Basophils%             -0.068298 -0.027215     0.081324          0.041617
# Basophils#             -0.043028 -0.007835     0.100122          0.090862
# Large Unstained Cells% -0.032489 -0.048923     0.051303          0.035740
# Large Unstained Cells#  0.040276 -0.037981    -0.023638         -0.000315
# Disease_Prediction     -0.739979 -0.795172    -0.048680         -0.045542
#
#                            M.C.V     M.C.H   M.C.H.C       RDW  \
# WBCS                   -0.030996 -0.094124 -0.055120  0.188647
# RBCs                   -0.039823 -0.064287 -0.074731  0.078891
# Haemoglobin             0.056299  0.166227  0.126552 -0.269535
# Hematocrit (PCV)        0.039758  0.100822  0.100805 -0.222649
# M.C.V                   1.000000  0.120896  0.021888 -0.081647
# M.C.H                   0.120896  1.000000  0.143532 -0.257420
# M.C.H.C                 0.021888  0.143532  1.000000 -0.188557
# RDW                    -0.081647 -0.257420 -0.188557  1.000000
# Platelets Count        -0.025947 -0.071553 -0.043941  0.071293
# MPV                     0.001489 -0.023341 -0.000056  0.027115
# Neutrophils%           -0.015453 -0.056977 -0.014920  0.063444
# Neutrophils#           -0.017172 -0.073985  0.034802  0.130381
# Lymphocytes%            0.008209  0.070203  0.016527 -0.128259
# Lymphocytes#           -0.021057 -0.062597 -0.051670  0.076016
# Monocyte%               0.008104 -0.070143 -0.087402  0.173597
# Monocyte#              -0.037976 -0.102619 -0.031781  0.188531
# Eosinophils%            0.046532  0.072561  0.080516 -0.138461
# Eosinophils#           -0.008206  0.000994  0.014476 -0.065908
# Basophils%              0.004177  0.027505  0.029796 -0.059505
# Basophils#              0.011864  0.048160  0.055128 -0.082636
# Large Unstained Cells%  0.000381 -0.002087  0.064383 -0.088923
# Large Unstained Cells#  0.025961  0.017888  0.019267 -0.005633
# Disease_Prediction      0.008911 -0.018066 -0.009648  0.049395
#
#                         Platelets Count       MPV  ...  Lymphocytes#  \
# WBCS                           0.669270  0.043953  ...      0.075279
# RBCs                           0.698370  0.011329  ...      0.000059
# Haemoglobin                   -0.026045 -0.033526  ...     -0.075679
# Hematocrit (PCV)              -0.043628 -0.050830  ...     -0.066478
# M.C.V                         -0.025947  0.001489  ...     -0.021057
# M.C.H                         -0.071553 -0.023341  ...     -0.062597
# M.C.H.C                       -0.043941 -0.000056  ...     -0.051670
# RDW                            0.071293  0.027115  ...      0.076016
# Platelets Count                1.000000 -0.000429  ...      0.016067
# MPV                           -0.000429  1.000000  ...      0.000621
# Neutrophils%                   0.006532  0.011171  ...      0.048456
# Neutrophils#                   0.024993  0.065912  ...      0.094188
# Lymphocytes%                   0.005529 -0.030530  ...     -0.064424
# Lymphocytes#                   0.016067  0.000621  ...      1.000000
# Monocyte%                      0.029826  0.063235  ...      0.033773
# Monocyte#                      0.101028  0.069170  ...      0.109251
# Eosinophils%                  -0.007466 -0.038738  ...     -0.066882
# Eosinophils#                   0.003838 -0.044605  ...     -0.026310
# Basophils%                    -0.011377 -0.004087  ...     -0.037341
# Basophils#                    -0.013686 -0.020522  ...     -0.037308
# Large Unstained Cells%        -0.034402 -0.002851  ...     -0.037541
# Large Unstained Cells#        -0.029341 -0.001878  ...     -0.035733
# Disease_Prediction            -0.766415  0.007286  ...      0.022389
#
#                         Monocyte%  Monocyte#  Eosinophils%  Eosinophils#  \
# WBCS                     0.030776   0.220958     -0.110309     -0.017828
# RBCs                     0.020555   0.062496     -0.007623     -0.017187
# Haemoglobin             -0.133075  -0.096082      0.141148      0.071946
# Hematocrit (PCV)        -0.138601  -0.077590      0.098799      0.067273
# M.C.V                    0.008104  -0.037976      0.046532     -0.008206
# M.C.H                   -0.070143  -0.102619      0.072561      0.000994
# M.C.H.C                 -0.087402  -0.031781      0.080516      0.014476
# RDW                      0.173597   0.188531     -0.138461     -0.065908
# Platelets Count          0.029826   0.101028     -0.007466      0.003838
# MPV                      0.063235   0.069170     -0.038738     -0.044605
# Neutrophils%            -0.077579   0.078721     -0.087394     -0.015439
# Neutrophils#            -0.051847   0.222005     -0.138571     -0.027028
# Lymphocytes%            -0.017126  -0.078805      0.089357     -0.001160
# Lymphocytes#             0.033773   0.109251     -0.066882     -0.026310
# Monocyte%                1.000000   0.080238     -0.018088      0.011670
# Monocyte#                0.080238   1.000000     -0.098566     -0.007288
# Eosinophils%            -0.018088  -0.098566      1.000000      0.149526
# Eosinophils#             0.011670  -0.007288      0.149526      1.000000
# Basophils%              -0.015583  -0.046318      0.075743      0.032126
# Basophils#              -0.083816  -0.010814      0.040880      0.018632
# Large Unstained Cells%  -0.008406  -0.009819      0.016984      0.001874
# Large Unstained Cells#  -0.018468   0.070950     -0.016049     -0.019290
# Disease_Prediction       0.034244  -0.021570     -0.041453     -0.006587
#
#                         Basophils%  Basophils#  Large Unstained Cells%  \
# WBCS                     -0.068298   -0.043028               -0.032489
# RBCs                     -0.027215   -0.007835               -0.048923
# Haemoglobin               0.081324    0.100122                0.051303
# Hematocrit (PCV)          0.041617    0.090862                0.035740
# M.C.V                     0.004177    0.011864                0.000381
# M.C.H                     0.027505    0.048160               -0.002087
# M.C.H.C                   0.029796    0.055128                0.064383
# RDW                      -0.059505   -0.082636               -0.088923
# Platelets Count          -0.011377   -0.013686               -0.034402
# MPV                      -0.004087   -0.020522               -0.002851
# Neutrophils%             -0.038320   -0.051902               -0.026544
# Neutrophils#             -0.068706    0.004763                0.000715
# Lymphocytes%              0.051517    0.025293                0.028639
# Lymphocytes#             -0.037341   -0.037308               -0.037541
# Monocyte%                -0.015583   -0.083816               -0.008406
# Monocyte#                -0.046318   -0.010814               -0.009819
# Eosinophils%              0.075743    0.040880                0.016984
# Eosinophils#              0.032126    0.018632                0.001874
# Basophils%                1.000000    0.049787                0.074277
# Basophils#                0.049787    1.000000                0.015135
# Large Unstained Cells%    0.074277    0.015135                1.000000
# Large Unstained Cells#    0.006137    0.010759                0.081940
# Disease_Prediction        0.001208   -0.010764               -0.007119
#
#                         Large Unstained Cells#  Disease_Prediction
# WBCS                                  0.040276           -0.739979
# RBCs                                 -0.037981           -0.795172
# Haemoglobin                          -0.023638           -0.048680
# Hematocrit (PCV)                     -0.000315           -0.045542
# M.C.V                                 0.025961            0.008911
# M.C.H                                 0.017888           -0.018066
# M.C.H.C                               0.019267           -0.009648
# RDW                                  -0.005633            0.049395
# Platelets Count                      -0.029341           -0.766415
# MPV                                  -0.001878            0.007286
# Neutrophils%                          0.035695           -0.010632
# Neutrophils#                          0.110984           -0.031135
# Lymphocytes%                         -0.006942            0.002530
# Lymphocytes#                         -0.035733            0.022389
# Monocyte%                            -0.018468            0.034244
# Monocyte#                             0.070950           -0.021570
# Eosinophils%                         -0.016049           -0.041453
# Eosinophils#                         -0.019290           -0.006587
# Basophils%                            0.006137            0.001208
# Basophils#                            0.010759           -0.010764
# Large Unstained Cells%                0.081940           -0.007119
# Large Unstained Cells#                1.000000           -0.011318
# Disease_Prediction                   -0.011318            1.000000
#
# [23 rows x 23 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(data.corr(),annot=True,fmt='0.2f',linewidth=0.5,cmap='Reds')
plt.show()

# %%
data.hist(figsize=(25,12))
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   WBCS                    2000 non-null   float64
#  1   RBCs                    2000 non-null   float64
#  2   Haemoglobin             2000 non-null   float64
#  3   Hematocrit (PCV)        2000 non-null   float64
#  4   M.C.V                   2000 non-null   float64
#  5   M.C.H                   2000 non-null   float64
#  6   M.C.H.C                 2000 non-null   float64
#  7   RDW                     2000 non-null   float64
#  8   Platelets Count         2000 non-null   float64
#  9   MPV                     2000 non-null   float64
#  10  Neutrophils%            2000 non-null   float64
#  11  Neutrophils#            2000 non-null   float64
#  12  Lymphocytes%            2000 non-null   float64
#  13  Lymphocytes#            2000 non-null   float64
#  14  Monocyte%               2000 non-null   float64
#  15  Monocyte#               2000 non-null   float64
#  16  Eosinophils%            2000 non-null   float64
#  17  Eosinophils#            2000 non-null   float64
#  18  Basophils%              2000 non-null   float64
#  19  Basophils#              2000 non-null   float64
#  20  Large Unstained Cells%  2000 non-null   float64
#  21  Large Unstained Cells#  2000 non-null   float64
#  22  Disease_Prediction      2000 non-null   int64
# dtypes: float64(22), int64(1)
# memory usage: 359.5 KB

# %%
sns.countplot(x=data['Disease_Prediction'] ,hue=data['WBCS'])
# Out:
# <Axes: xlabel='Disease_Prediction', ylabel='count'>

# %% [markdown]
# # Create Models

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score,recall_score,f1_score
from sklearn.metrics import classification_report

# %%
x=data.drop(['Disease_Prediction'],axis=1)
y=data['Disease_Prediction']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y ,train_size=0.8 ,random_state=42)

# %%
model1=LogisticRegression()
model2=SVC()
model3=DecisionTreeClassifier()
model4=RandomForestClassifier(n_estimators=1000,class_weight='balanced')
model5=GradientBoostingClassifier(n_estimators=4000)
model6=GaussianNB()

# %%
Algorithms=['LogisticRegression','SVC','DecisionTreeClassifier','RandomForestClassifier','GradientBoostingClassifier','GaussianNB']
accus=[]
recs=[]
f1s=[]

# %%
def cal(model):
    model.fit(x_train,y_train)
    pre=model.predict(x_test)
    accuracy=accuracy_score(pre,y_test)
    recall=recall_score(pre,y_test, average='weighted')
    f1=f1_score(pre,y_test, average='weighted')
    plt.figure(figsize=(4,2))
    sns.heatmap(confusion_matrix(pre,y_test),annot=True,fmt='0.2f',linewidth=0.5)
    confusion_matrix(pre,y_test)
    
    accus.append(accuracy)
    recs.append(recall)
    f1s.append(f1)
    
    print(model)
    print('accuracy_score is : ',accuracy)
    print('recall_score is : ',recall)
    print('f1_score is : ',f1)

# %%
cal(model1)
# Out:
# LogisticRegression()
# accuracy_score is :  0.9575
# recall_score is :  0.9575
# f1_score is :  0.9574986716674481

# %%
cal(model2)
# Out:
# SVC()
# accuracy_score is :  0.945
# recall_score is :  0.945
# f1_score is :  0.945

# %%
cal(model3)
# Out:
# DecisionTreeClassifier()
# accuracy_score is :  0.985
# recall_score is :  0.985
# f1_score is :  0.9850037523452159

# %%
cal(model4)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=1000)
# accuracy_score is :  0.985
# recall_score is :  0.985
# f1_score is :  0.9850015006002402

# %%
cal(model5)
# Out:
# GradientBoostingClassifier(n_estimators=4000)
# accuracy_score is :  0.985
# recall_score is :  0.985
# f1_score is :  0.9850037523452159

# %%
cal(model6)
# Out:
# GaussianNB()
# accuracy_score is :  0.91
# recall_score is :  0.91
# f1_score is :  0.9107727272727274

# %%
final=pd.DataFrame({'Algorithm':Algorithms,'accuracy_score':accus,'recall_score':recs,'f1_score':f1s})
final
# Out:
#                     Algorithm  accuracy_score  recall_score  f1_score
# 0          LogisticRegression          0.9575        0.9575  0.957499
# 1                         SVC          0.9450        0.9450  0.945000
# 2      DecisionTreeClassifier          0.9850        0.9850  0.985004
# 3      RandomForestClassifier          0.9850        0.9850  0.985002
# 4  GradientBoostingClassifier          0.9850        0.9850  0.985004
# 5                  GaussianNB          0.9100        0.9100  0.910773

# %%
fig,ax=plt.subplots(figsize=(20,5))
plt.plot(final.Algorithm,accus,label='accuracy_score',marker='o')
plt.title('plot for accuracy_score')
plt.legend()
plt.show()

# %%
fig,ax=plt.subplots(figsize=(20,5))
plt.plot(final.Algorithm,recs,label='recall_score',marker='o')
plt.title('plot for recall_score')
plt.legend()
plt.show()

# %%
fig,ax=plt.subplots(figsize=(20,5))
plt.plot(final.Algorithm,f1s,label='f1_score',marker='o')
plt.title('plot for f1_score')
plt.legend()
plt.show()

# %% [markdown]
# # Take Our Model

# %%
import pickle
import joblib

with open('Gradient_Boosting_Classifier_model.pkl', 'wb') as f:
    pickle.dump(model5, f)
print("Model saved as pickle → Gradient_Boosting_Classifier_model.pkl")

joblib.dump(model5, 'Gradient_Boosting_Classifier_model.joblib')
print("Model saved as joblib → Gradient_Boosting_Classifier_model.joblib")
# Out:
# Model saved as pickle → Gradient_Boosting_Classifier_model.pkl
# Model saved as joblib → Gradient_Boosting_Classifier_model.joblib

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   WBCS                    2000 non-null   float64
#  1   RBCs                    2000 non-null   float64
#  2   Haemoglobin             2000 non-null   float64
#  3   Hematocrit (PCV)        2000 non-null   float64
#  4   M.C.V                   2000 non-null   float64
#  5   M.C.H                   2000 non-null   float64
#  6   M.C.H.C                 2000 non-null   float64
#  7   RDW                     2000 non-null   float64
#  8   Platelets Count         2000 non-null   float64
#  9   MPV                     2000 non-null   float64
#  10  Neutrophils%            2000 non-null   float64
#  11  Neutrophils#            2000 non-null   float64
#  12  Lymphocytes%            2000 non-null   float64
#  13  Lymphocytes#            2000 non-null   float64
#  14  Monocyte%               2000 non-null   float64
#  15  Monocyte#               2000 non-null   float64
#  16  Eosinophils%            2000 non-null   float64
#  17  Eosinophils#            2000 non-null   float64
#  18  Basophils%              2000 non-null   float64
#  19  Basophils#              2000 non-null   float64
#  20  Large Unstained Cells%  2000 non-null   float64
#  21  Large Unstained Cells#  2000 non-null   float64
#  22  Disease_Prediction      2000 non-null   int64
# dtypes: float64(22), int64(1)
# memory usage: 359.5 KB
